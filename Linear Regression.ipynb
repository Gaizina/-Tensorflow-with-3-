# %%
import tensorflow as tf

x_data = [1, 2, 3]
y_data = [1, 2, 3]

# %%
W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.random_uniform([1], -1.0, 1.0))

# %%
X = tf.placeholder(tf.float32, name="X")
Y = tf.placeholder(tf.float32, name="Y")

# %%
hypothesis = W * X + b

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.1)
train_op = optimizer.minimize(cost)

# %%
with tf.Session() as sess:
    sess. run(tf.global_variables_initializer())
    
    for step in range(100):
        _, cost_val = sess.run([train_op, cost], feed_dict={X: x_data,
                                                            Y: y_data})
        
        
        print(step, cost_val, sess.run(W), sess.run(b))
        
    print("\n=== Test ===")
    print("X: 5, Y:", sess.run(hypothesis, feed_dict={X: 5}))
    print("X: 2.5, Y:", sess.run(hypothesis, feed_dict={X: 2.5}))
# Out:
# 0 3.6015732 [1.2862062] [-0.43289688]
# 1 0.07407396 [1.1922392] [-0.46080002]
# 2 0.03046227 [1.1971359] [-0.4455357]
# 3 0.028536359 [1.1913567] [-0.43528292]
# 4 0.027175149 [1.1868703] [-0.42476898]
# 5 0.02588424 [1.1823657] [-0.41456333]
# 6 0.024654707 [1.177983] [-0.40459692]
# 7 0.023483591 [1.1737044] [-0.39487076]
# 8 0.022368116 [1.1695286] [-0.38537836]
# 9 0.021305623 [1.1654532] [-0.37611413]
# 10 0.02029358 [1.1614759] [-0.36707258]
# 11 0.01932962 [1.1575941] [-0.3582484]
# 12 0.018411435 [1.1538057] [-0.34963635]
# 13 0.017536892 [1.1501082] [-0.34123138]
# 14 0.016703865 [1.1464998] [-0.33302838]
# 15 0.015910441 [1.142978] [-0.3250226]
# 16 0.01515466 [1.1395409] [-0.31720927]
# 17 0.014434811 [1.1361865] [-0.30958378]
# 18 0.01374915 [1.1329126] [-0.3021416]
# 19 0.013096053 [1.1297175] [-0.29487833]
# 20 0.0124739995 [1.1265991] [-0.28778967]
# 21 0.011881467 [1.1235558] [-0.28087136]
# 22 0.011317086 [1.1205856] [-0.2741194]
# 23 0.010779512 [1.1176867] [-0.26752976]
# 24 0.010267471 [1.1148577] [-0.2610985]
# 25 0.009779766 [1.1120965] [-0.25482187]
# 26 0.00931522 [1.1094018] [-0.24869612]
# 27 0.008872737 [1.1067718] [-0.24271764]
# 28 0.008451257 [1.1042053] [-0.23688284]
# 29 0.008049828 [1.1017002] [-0.23118837]
# 30 0.007667456 [1.0992553] [-0.22563076]
# 31 0.007303247 [1.0968693] [-0.22020674]
# 32 0.006956332 [1.0945407] [-0.21491311]
# 33 0.0066259135 [1.092268] [-0.20974678]
# 34 0.0063111708 [1.09005] [-0.20470461]
# 35 0.006011395 [1.0878851] [-0.19978368]
# 36 0.005725847 [1.0857725] [-0.19498101]
# 37 0.005453855 [1.0837106] [-0.19029382]
# 38 0.005194793 [1.0816983] [-0.18571927]
# 39 0.0049480377 [1.0797343] [-0.18125473]
# 40 0.0047130133 [1.0778174] [-0.17689753]
# 41 0.0044891364 [1.0759468] [-0.172645]
# 42 0.004275893 [1.0741211] [-0.16849472]
# 43 0.0040727933 [1.0723393] [-0.16444424]
# 44 0.003879329 [1.0706003] [-0.16049111]
# 45 0.003695054 [1.0689032] [-0.15663299]
# 46 0.0035195465 [1.0672467] [-0.15286767]
# 47 0.0033523634 [1.0656302] [-0.14919282]
# 48 0.0031931202 [1.0640525] [-0.14560634]
# 49 0.0030414423 [1.0625128] [-0.14210606]
# 50 0.0028969713 [1.06101] [-0.13868994]
# 51 0.002759369 [1.0595433] [-0.13535595]
# 52 0.0026282975 [1.0581119] [-0.13210207]
# 53 0.0025034493 [1.0567149] [-0.12892643]
# 54 0.0023845243 [1.0553516] [-0.12582709]
# 55 0.0022712618 [1.054021] [-0.12280231]
# 56 0.0021633834 [1.0527223] [-0.11985026]
# 57 0.002060618 [1.0514549] [-0.11696914]
# 58 0.0019627323 [1.050218] [-0.11415727]
# 59 0.0018695035 [1.0490108] [-0.111413]
# 60 0.0017807013 [1.0478326] [-0.1087347]
# 61 0.0016961232 [1.0466827] [-0.10612082]
# 62 0.001615548 [1.0455605] [-0.10356973]
# 63 0.0015388131 [1.0444652] [-0.10107998]
# 64 0.0014657186 [1.0433964] [-0.09865007]
# 65 0.0013960934 [1.0423532] [-0.09627859]
# 66 0.0013297762 [1.041335] [-0.09396413]
# 67 0.001266609 [1.0403414] [-0.09170529]
# 68 0.0012064482 [1.0393716] [-0.08950078]
# 69 0.0011491455 [1.0384251] [-0.08734928]
# 70 0.001094561 [1.0375013] [-0.08524948]
# 71 0.0010425645 [1.0365999] [-0.08320012]
# 72 0.0009930386 [1.0357201] [-0.08120004]
# 73 0.0009458706 [1.0348613] [-0.07924807]
# 74 0.00090093963 [1.0340233] [-0.07734298]
# 75 0.000858146 [1.0332054] [-0.07548369]
# 76 0.000817379 [1.0324072] [-0.0736691]
# 77 0.0007785523 [1.0316281] [-0.07189813]
# 78 0.00074157206 [1.0308678] [-0.07016975]
# 79 0.0007063502 [1.0301257] [-0.06848293]
# 80 0.00067279924 [1.0294015] [-0.06683666]
# 81 0.0006408392 [1.0286947] [-0.06522994]
# 82 0.00061040063 [1.0280049] [-0.06366187]
# 83 0.00058140425 [1.0273317] [-0.06213146]
# 84 0.00055378553 [1.0266747] [-0.06063785]
# 85 0.00052747974 [1.0260335] [-0.05918017]
# 86 0.00050242693 [1.0254077] [-0.05775755]
# 87 0.0004785584 [1.0247968] [-0.0563691]
# 88 0.00045582792 [1.0242008] [-0.05501401]
# 89 0.0004341765 [1.0236189] [-0.05369153]
# 90 0.0004135508 [1.0230513] [-0.05240079]
# 91 0.00039390792 [1.022497] [-0.05114113]
# 92 0.00037519765 [1.0219562] [-0.04991173]
# 93 0.00035737522 [1.0214285] [-0.04871186]
# 94 0.00034039895 [1.0209134] [-0.04754087]
# 95 0.000324231 [1.0204105] [-0.04639804]
# 96 0.00030883044 [1.0199199] [-0.04528265]
# 97 0.0002941599 [1.019441] [-0.04419408]
# 98 0.0002801868 [1.0189737] [-0.04313166]
# 99 0.00026687697 [1.0185176] [-0.0420948]
#
# === Test ===
# X: 5, Y: [5.0504932]
# X: 2.5, Y: [2.5041993]
